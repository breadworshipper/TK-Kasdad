# %%
# import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("dataframe/UFC_Test_Classif_X.csv")
df.head()
# Out:
#    id      R_fighter       B_fighter               Referee        date  \
# 0   0   Tecia Torres    Juliana Lima         Chris Tognoni  2017-07-07
# 1   1    John Howard   Lorenz Larkin             Herb Dean  2015-01-18
# 2   2  Kyle Bochniak  Jeremy Kennedy  Todd Ronald Anderson  2017-07-22
# 3   3     Yao Zhikui     Royston Wee        Steve Perceval  2014-08-23
# 4   4  Carlos Newton    Pat Miletich         John McCarthy  2001-05-04
#
#                          location  title_bout      weight_class  B_avg_KD  \
# 0          Las Vegas, Nevada, USA       False  WomenStrawweight       0.0
# 1      Boston, Massachusetts, USA       False      Welterweight       0.0
# 2        Uniondale, New York, USA       False     Featherweight       0.0
# 3                    Macau, China       False      Bantamweight       0.0
# 4  Atlantic City, New Jersey, USA        True      Welterweight       0.0
#
#    B_avg_opp_KD  ...  R_win_by_Decision_Unanimous  R_win_by_KO/TKO  \
# 0          0.00  ...                            4                0
# 1          0.25  ...                            1                2
# 2          0.50  ...                            0                0
# 3          0.00  ...                            0                0
# 4          0.00  ...                            0                0
#
#    R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_Stance  R_Height_cms  \
# 0                    0                             0  Orthodox        154.94
# 1                    0                             0  Orthodox        170.18
# 2                    0                             0  Orthodox        170.18
# 3                    0                             0  Orthodox        165.10
# 4                    1                             0  Orthodox        175.26
#
#    R_Reach_cms  R_Weight_lbs  B_age  R_age
# 0       152.40         115.0   35.0   27.0
# 1       182.88         170.0   28.0   31.0
# 2       177.80         145.0   24.0   30.0
# 3       162.56         125.0   27.0   23.0
# 4          NaN         170.0   33.0   24.0
#
# [5 rows x 143 columns]

# %%
# Delete duplicate
print(f"Shape before dropping duplicates : {df.shape}") # Before dropping duplicates
df.drop_duplicates(inplace=True)
print(f"Shape after dropping duplicates: {df.shape}") # After dropping duplicates
# Out:
# Shape before dropping duplicates : (602, 143)
# Shape after dropping duplicates: (602, 143)

# %%
def check_null(df):
    col_na = df.isnull().sum().sort_values(ascending=True)
    percent = col_na / len(df)
    missing_data = pd.concat([col_na, percent], axis=1, keys=['Total', 'Percent'])

    if (missing_data[missing_data['Total'] > 0].shape[0] == 0):
        print("Tidak ditemukan missing value pada dataset")
    else:
        print(missing_data[missing_data['Total'] > 0])

# %%
check_null(df)
# Out:
#                           Total   Percent
# Referee                       1  0.001661
# R_Stance                      2  0.003322
# B_Stance                      2  0.003322
# R_age                         7  0.011628
# B_age                        11  0.018272
# ...                         ...       ...
# B_avg_CTRL_time(seconds)    134  0.222591
# B_avg_opp_GROUND_att        134  0.222591
# B_avg_GROUND_landed         134  0.222591
# B_avg_BODY_landed           134  0.222591
# B_avg_DISTANCE_att          134  0.222591
#
# [104 rows x 2 columns]

# %%
# Split string and number
# Split dataframe into object type and number type
df_object = df.select_dtypes(include='object')
df_number = df.select_dtypes(include=np.number)

# %%
df_number_imputed = df_number.fillna(df_number.median())

# %%
df
# Out:
#       id         R_fighter        B_fighter               Referee        date  \
# 0      0      Tecia Torres     Juliana Lima         Chris Tognoni  2017-07-07
# 1      1       John Howard    Lorenz Larkin             Herb Dean  2015-01-18
# 2      2     Kyle Bochniak   Jeremy Kennedy  Todd Ronald Anderson  2017-07-22
# 3      3        Yao Zhikui      Royston Wee        Steve Perceval  2014-08-23
# 4      4     Carlos Newton     Pat Miletich         John McCarthy  2001-05-04
# ..   ...               ...              ...                   ...         ...
# 597  597     Julianna Pena  Jessica Rakoczy        Mario Yamasaki  2013-11-30
# 598  598     Jake Matthews  Andrew Holbrook            John Sharp  2016-11-26
# 599  599  Gregor Gillespie   Yancy Medeiros  Todd Ronald Anderson  2019-01-19
# 600  600         Pat Barry     Shawn Jordan           Jerin Valel  2013-06-15
# 601  601      Louis Smolka   Ryan MacDonald           John Cooper  2019-09-14
#
#                                 location  title_bout       weight_class  \
# 0                 Las Vegas, Nevada, USA       False   WomenStrawweight
# 1             Boston, Massachusetts, USA       False       Welterweight
# 2               Uniondale, New York, USA       False      Featherweight
# 3                           Macau, China       False       Bantamweight
# 4         Atlantic City, New Jersey, USA        True       Welterweight
# ..                                   ...         ...                ...
# 597               Las Vegas, Nevada, USA        True  WomenBantamweight
# 598       Melbourne, Victoria, Australia       False        Lightweight
# 599              Brooklyn, New York, USA       False        Lightweight
# 600           Winnipeg, Manitoba, Canada       False        Heavyweight
# 601  Vancouver, British Columbia, Canada       False       Bantamweight
#
#      B_avg_KD  B_avg_opp_KD  ...  R_win_by_Decision_Unanimous  \
# 0     0.00000      0.000000  ...                            4
# 1     0.00000      0.250000  ...                            1
# 2     0.00000      0.500000  ...                            0
# 3     0.00000      0.000000  ...                            0
# 4     0.00000      0.000000  ...                            0
# ..        ...           ...  ...                          ...
# 597       NaN           NaN  ...                            0
# 598   0.00000      0.500000  ...                            0
# 599   0.80127      2.015625  ...                            1
# 600   0.00000      0.000000  ...                            1
# 601   0.00000      0.000000  ...                            2
#
#      R_win_by_KO/TKO  R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  \
# 0                  0                    0                             0
# 1                  2                    0                             0
# 2                  0                    0                             0
# 3                  0                    0                             0
# 4                  0                    1                             0
# ..               ...                  ...                           ...
# 597                0                    0                             0
# 598                0                    3                             1
# 599                2                    2                             0
# 600                4                    0                             0
# 601                2                    2                             0
#
#      R_Stance  R_Height_cms  R_Reach_cms  R_Weight_lbs  B_age  R_age
# 0    Orthodox        154.94       152.40         115.0   35.0   27.0
# 1    Orthodox        170.18       182.88         170.0   28.0   31.0
# 2    Orthodox        170.18       177.80         145.0   24.0   30.0
# 3    Orthodox        165.10       162.56         125.0   27.0   23.0
# 4    Orthodox        175.26          NaN         170.0   33.0   24.0
# ..        ...           ...          ...           ...    ...    ...
# 597  Orthodox        167.64       175.26         135.0   36.0   24.0
# 598  Orthodox        180.34       185.42         170.0   30.0   22.0
# 599  Orthodox        170.18       180.34         155.0   31.0   32.0
# 600  Orthodox        180.34       187.96         235.0   28.0   33.0
# 601  Orthodox        175.26       172.72         135.0   26.0   28.0
#
# [602 rows x 143 columns]

# %%
# Drop R_fighter, B_fighter, Referee, location, and date
df_object = df_object.drop(['R_fighter', 'B_fighter', 'Referee', 'location', 'date'], axis=1)

# %%
# Combine df_object and df_imputed_number
df = pd.concat([df_object, df_number_imputed], axis=1)
df.head()
# Out:
#        weight_class  B_Stance  R_Stance  id  B_avg_KD  B_avg_opp_KD  \
# 0  WomenStrawweight  Orthodox  Orthodox   0       0.0          0.00
# 1      Welterweight  Orthodox  Orthodox   1       0.0          0.25
# 2     Featherweight  Orthodox  Orthodox   2       0.0          0.50
# 3      Bantamweight  Orthodox  Orthodox   3       0.0          0.00
# 4      Welterweight  Orthodox  Orthodox   4       0.0          0.00
#
#    B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  \
# 0           0.493750               0.448750      0.475000          0.177500
# 1           0.473125               0.371875      0.000000          0.203750
# 2           0.500000               0.480000      0.615000          0.000000
# 3           0.660000               0.690000      0.850000          0.000000
# 4           0.505312               0.439375      0.815937          0.067187
#
#    ...  R_win_by_Decision_Split  R_win_by_Decision_Unanimous  R_win_by_KO/TKO  \
# 0  ...                        0                            4                0
# 1  ...                        3                            1                2
# 2  ...                        1                            0                0
# 3  ...                        0                            0                0
# 4  ...                        0                            0                0
#
#    R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_Height_cms  \
# 0                    0                             0        154.94
# 1                    0                             0        170.18
# 2                    0                             0        170.18
# 3                    0                             0        165.10
# 4                    1                             0        175.26
#
#    R_Reach_cms  R_Weight_lbs  B_age  R_age
# 0       152.40         115.0   35.0   27.0
# 1       182.88         170.0   28.0   31.0
# 2       177.80         145.0   24.0   30.0
# 3       162.56         125.0   27.0   23.0
# 4       182.88         170.0   33.0   24.0
#
# [5 rows x 137 columns]

# %%
# Impute missing R_stance and B_stance with mode
df['R_Stance'].fillna(df['R_Stance'].mode()[0], inplace=True)
df['B_Stance'].fillna(df['B_Stance'].mode()[0], inplace=True)

# %%
check_null(df)
# Out:
# Tidak ditemukan missing value pada dataset

# %%
def check_outlier(df):
    Q1 = df.quantile(0.25)
    Q3 = df.quantile(0.75)

    # Menghitung RUB dan RLB.
    IQR = Q3 - Q1
    lower_limit = Q1 - 1.5*IQR
    upper_limit = Q3 + 1.5*IQR

    # Menampilkan banyaknya outlier pada atribut.
    outliers = (df < lower_limit) | (df > upper_limit)
    print ("Outlier pada tiap atribut:")
    print(outliers.sum())

    return outliers

# %%
# Split string and number
# Split dataframe into object type and number type
df_object = df.select_dtypes(include='object')
df_number = df.select_dtypes(include=np.number)

# %%
outliers = dict(check_outlier(df_number).sum())
print("\n\npercentage of outliers in each column:")
for key in outliers.keys():
    print(f"{key} = {outliers[key]/df_number[key].shape[0] * 100}%")
# Out:
# Outlier pada tiap atribut:
# id                         0
# B_avg_KD                  49
# B_avg_opp_KD             126
# B_avg_SIG_STR_pct         66
# B_avg_opp_SIG_STR_pct     54
#                         ...
# R_Height_cms               3
# R_Reach_cms               11
# R_Weight_lbs              32
# B_age                     11
# R_age                      1
# Length: 134, dtype: int64
#
#
# percentage of outliers in each column:
# id = 0.0%
# B_avg_KD = 8.13953488372093%
# B_avg_opp_KD = 20.930232558139537%
# B_avg_SIG_STR_pct = 10.96345514950166%
# B_avg_opp_SIG_STR_pct = 8.970099667774086%
# B_avg_TD_pct = 4.318936877076411%
# B_avg_opp_TD_pct = 6.64451827242525%
# B_avg_SUB_ATT = 7.807308970099667%
# B_avg_opp_SUB_ATT = 5.647840531561462%
# B_avg_REV = 21.428571428571427%
# B_avg_opp_REV = 23.920265780730897%
# B_avg_SIG_STR_att = 5.48172757475083%
# B_avg_SIG_STR_landed = 4.485049833887043%
# B_avg_opp_SIG_STR_att = 4.983388704318937%
# B_avg_opp_SIG_STR_landed = 5.3156146179401995%
# B_avg_TOTAL_STR_att = 5.3156146179401995%
# B_avg_TOTAL_STR_landed = 3.6544850498338874%
# B_avg_opp_TOTAL_STR_att = 3.820598006644518%
# B_avg_opp_TOTAL_STR_landed = 5.647840531561462%
# B_avg_TD_att = 8.471760797342192%
# B_avg_TD_landed = 10.132890365448505%
# B_avg_opp_TD_att = 6.810631229235881%
# B_avg_opp_TD_landed = 9.966777408637874%
# B_avg_HEAD_att = 6.4784053156146175%
# B_avg_HEAD_landed = 5.813953488372093%
# B_avg_opp_HEAD_att = 5.48172757475083%
# B_avg_opp_HEAD_landed = 6.4784053156146175%
# B_avg_BODY_att = 8.471760797342192%
# B_avg_BODY_landed = 7.308970099667775%
# B_avg_opp_BODY_att = 5.3156146179401995%
# B_avg_opp_BODY_landed = 5.48172757475083%
# B_avg_LEG_att = 7.807308970099667%
# B_avg_LEG_landed = 7.475083056478406%
# B_avg_opp_LEG_att = 7.807308970099667%
# B_avg_opp_LEG_landed = 6.976744186046512%
# B_avg_DISTANCE_att = 6.64451827242525%
# B_avg_DISTANCE_landed = 7.142857142857142%
# B_avg_opp_DISTANCE_att = 5.149501661129568%
# B_avg_opp_DISTANCE_landed = 6.976744186046512%
# B_avg_CLINCH_att = 9.800664451827243%
# B_avg_CLINCH_landed = 9.800664451827243%
# B_avg_opp_CLINCH_att = 4.485049833887043%
# B_avg_opp_CLINCH_landed = 5.48172757475083%
# B_avg_GROUND_att = 8.803986710963455%
# B_avg_GROUND_landed = 9.46843853820598%
# B_avg_opp_GROUND_att = 12.790697674418606%
# B_avg_opp_GROUND_landed = 12.29235880398671%
# B_avg_CTRL_time(seconds) = 8.970099667774086%
# B_avg_opp_CTRL_time(seconds) = 6.312292358803987%
# B_total_time_fought(seconds) = 0.16611295681063123%
# B_total_rounds_fought = 5.149501661129568%
# B_total_title_bouts = 12.29235880398671%
# B_current_win_streak = 9.966777408637874%
# B_current_lose_streak = 1.3289036544850499%
# B_longest_win_streak = 2.823920265780731%
# B_wins = 3.488372093023256%
# B_losses = 5.48172757475083%
# B_draw = 0.0%
# B_win_by_Decision_Majority = 0.9966777408637874%
# B_win_by_Decision_Split = 17.109634551495017%
# B_win_by_Decision_Unanimous = 11.295681063122924%
# B_win_by_KO/TKO = 11.794019933554816%
# B_win_by_Submission = 5.3156146179401995%
# B_win_by_TKO_Doctor_Stoppage = 3.6544850498338874%
# B_Height_cms = 0.33222591362126247%
# B_Weight_lbs = 4.318936877076411%
# R_avg_KD = 7.475083056478406%
# R_avg_opp_KD = 6.146179401993355%
# R_avg_SIG_STR_pct = 4.983388704318937%
# R_avg_opp_SIG_STR_pct = 2.990033222591362%
# R_avg_TD_pct = 1.9933554817275747%
# R_avg_opp_TD_pct = 1.8272425249169437%
# R_avg_SUB_ATT = 8.471760797342192%
# R_avg_opp_SUB_ATT = 7.142857142857142%
# R_avg_REV = 18.93687707641196%
# R_avg_opp_REV = 22.425249169435215%
# R_avg_SIG_STR_att = 4.152823920265781%
# R_avg_SIG_STR_landed = 3.820598006644518%
# R_avg_opp_SIG_STR_att = 2.823920265780731%
# R_avg_opp_SIG_STR_landed = 3.820598006644518%
# R_avg_TOTAL_STR_att = 3.1561461794019934%
# R_avg_TOTAL_STR_landed = 3.9867109634551494%
# R_avg_opp_TOTAL_STR_att = 3.322259136212625%
# R_avg_opp_TOTAL_STR_landed = 3.488372093023256%
# R_avg_TD_att = 5.3156146179401995%
# R_avg_TD_landed = 3.9867109634551494%
# R_avg_opp_TD_att = 4.651162790697675%
# R_avg_opp_TD_landed = 4.651162790697675%
# R_avg_HEAD_att = 4.485049833887043%
# R_avg_HEAD_landed = 5.149501661129568%
# R_avg_opp_HEAD_att = 3.820598006644518%
# R_avg_opp_HEAD_landed = 5.149501661129568%
# R_avg_BODY_att = 6.976744186046512%
# R_avg_BODY_landed = 6.4784053156146175%
# R_avg_opp_BODY_att = 3.820598006644518%
# R_avg_opp_BODY_landed = 4.651162790697675%
# R_avg_LEG_att = 4.817275747508306%
# R_avg_LEG_landed = 3.820598006644518%
# R_avg_opp_LEG_att = 5.647840531561462%
# R_avg_opp_LEG_landed = 4.983388704318937%
# R_avg_DISTANCE_att = 3.9867109634551494%
# R_avg_DISTANCE_landed = 4.152823920265781%
# R_avg_opp_DISTANCE_att = 2.990033222591362%
# R_avg_opp_DISTANCE_landed = 2.990033222591362%
# R_avg_CLINCH_att = 5.647840531561462%
# R_avg_CLINCH_landed = 7.142857142857142%
# R_avg_opp_CLINCH_att = 6.312292358803987%
# R_avg_opp_CLINCH_landed = 7.807308970099667%
# R_avg_GROUND_att = 7.142857142857142%
# R_avg_GROUND_landed = 6.4784053156146175%
# R_avg_opp_GROUND_att = 9.46843853820598%
# R_avg_opp_GROUND_landed = 8.970099667774086%
# R_avg_CTRL_time(seconds) = 3.1561461794019934%
# R_avg_opp_CTRL_time(seconds) = 4.651162790697675%
# R_total_time_fought(seconds) = 0.33222591362126247%
# R_total_rounds_fought = 7.641196013289036%
# R_total_title_bouts = 23.421926910299003%
# R_current_win_streak = 2.990033222591362%
# R_current_lose_streak = 0.9966777408637874%
# R_longest_win_streak = 4.983388704318937%
# R_wins = 5.813953488372093%
# R_losses = 4.485049833887043%
# R_draw = 0.0%
# R_win_by_Decision_Majority = 2.990033222591362%
# R_win_by_Decision_Split = 24.418604651162788%
# R_win_by_Decision_Unanimous = 3.9867109634551494%
# R_win_by_KO/TKO = 3.9867109634551494%
# R_win_by_Submission = 8.305647840531561%
# R_win_by_TKO_Doctor_Stoppage = 7.142857142857142%
# R_Height_cms = 0.4983388704318937%
# R_Reach_cms = 1.8272425249169437%
# R_Weight_lbs = 5.3156146179401995%
# B_age = 1.8272425249169437%
# R_age = 0.16611295681063123%

# %%
# Add a constant value to make all values positive
df_reach = df_number['B_Reach_cms']
df_number_positive = df_number + abs(df_number.min()) + 1

df_number_log = np.log(df_number_positive)
df_number_log['B_Reach_cms'] = df_reach
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'B_Reach_cms'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Add a constant value to make all values positive
# ----> 2 df_reach = df_number['B_Reach_cms']
#       3 df_number_positive = df_number + abs(df_number.min()) + 1
#       5 df_number_log = np.log(df_number_positive)
#
# File c:\Python311\Lib\site-packages\pandas\core\frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'B_Reach_cms'

# %%
df_id = df_test_number['id']
df_test_number.drop(['id'], axis=1, inplace=True)
df_test_number_positive = df_test_number + abs(df_test_number.min()) + 1
df_test_number_log = np.log(df_test_number_positive)
df_test_number_log = pd.concat([df_id, df_test_number_log], axis=1)

# %%
df_number_log
# Out:
#       B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  \
# 0     0.015504      0.000000           0.371564               0.355925
# 1     0.768371      0.000000           0.332278               0.301897
# 2     0.015504      0.000000           0.371564               0.355925
# 3     0.527867      0.000000           0.578499               0.170204
# 4     0.405465      0.236337           0.323143               0.376076
# ...        ...           ...                ...                    ...
# 5405  0.117783      0.000000           0.392886               0.435024
# 5406  0.015504      0.000000           0.325686               0.272796
# 5407  0.223144      0.223144           0.471565               0.415415
# 5408  0.628609      0.117783           0.433810               0.355049
# 5409  0.405465      0.000000           0.294534               0.357674
#
#       B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  B_avg_opp_SUB_ATT  \
# 0         0.223144          0.182322       0.145182           0.117783
# 1         0.214481          0.011419       0.145182           0.124703
# 2         0.223144          0.182322       0.145182           0.117783
# 3         0.084600          0.099280       0.089612           0.060625
# 4         0.357405          0.384970       0.866230           0.000244
# ...            ...               ...            ...                ...
# 5405      0.543051          0.361165       0.485508           0.318454
# 5406      0.478694          0.183688       0.441275           0.286705
# 5407      0.285179          0.285179       0.223144           0.000000
# 5408      0.030772          0.149497       0.000000           0.015504
# 5409      0.223144          0.048790       0.559616           0.000000
#
#       B_avg_REV  B_avg_opp_REV  ...  R_win_by_Decision_Split  \
# 0      0.000000       0.000000  ...                 0.000000
# 1      0.000000       0.000000  ...                 0.000000
# 2      0.000000       0.000000  ...                 0.000000
# 3      0.000000       0.000000  ...                 0.693147
# 4      0.117783       0.405465  ...                 0.000000
# ...         ...            ...  ...                      ...
# 5405   0.810930       0.117783  ...                 0.000000
# 5406   0.009718       0.119518  ...                 0.000000
# 5407   0.000000       0.000000  ...                 0.000000
# 5408   0.000000       0.000000  ...                 0.693147
# 5409   0.000000       0.000000  ...                 0.000000
#
#       R_win_by_Decision_Unanimous  R_win_by_KO/TKO  R_win_by_Submission  \
# 0                        0.000000         0.000000             0.000000
# 1                        1.609438         0.000000             0.693147
# 2                        0.000000         0.000000             0.000000
# 3                        1.791759         1.945910             1.386294
# 4                        1.098612         1.386294             0.000000
# ...                           ...              ...                  ...
# 5405                     0.693147         0.000000             0.000000
# 5406                     1.609438         0.693147             1.791759
# 5407                     0.000000         0.000000             0.000000
# 5408                     1.609438         0.693147             0.000000
# 5409                     0.693147         1.609438             0.693147
#
#       R_win_by_TKO_Doctor_Stoppage  R_Height_cms  R_Reach_cms  R_Weight_lbs  \
# 0                         0.000000      5.817944     5.802722      5.707110
# 1                         0.000000      5.810362     5.832938      5.655992
# 2                         0.000000      5.825469     5.817944      5.655992
# 3                         0.000000      5.802722     5.825469      5.655992
# 4                         0.693147      5.747544     5.771566      5.525453
# ...                            ...           ...          ...           ...
# 5405                      0.000000      5.795024     5.810362      5.602119
# 5406                      0.000000      5.825469     5.817944      5.655992
# 5407                      0.000000      5.795024     5.802722      5.564520
# 5408                      0.000000      5.795024     5.810362      5.602119
# 5409                      0.000000      5.840351     5.862267      5.846439
#
#          B_age     R_age
# 0     3.806662  3.713572
# 1     3.828641  3.912023
# 2     3.850148  3.931826
# 3     3.850148  3.988984
# 4     3.970292  3.931826
# ...        ...       ...
# 5405  3.806662  3.891820
# 5406  3.850148  3.988984
# 5407  3.761200  3.912023
# 5408  3.828641  3.988984
# 5409  3.931826  3.931826
#
# [5410 rows x 134 columns]

# %%
outliers = dict(check_outlier(df_number_log).sum())
print("\n\npercentage of outliers in each column:")
for key in outliers.keys():
    print(f"{key} = {outliers[key]/df_number_log[key].shape[0] * 100}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 outliers = dict(check_outlier(df_number_log).sum())
#       2 print("\n\npercentage of outliers in each column:")
#       3 for key in outliers.keys():
#
# NameError: name 'df_number_log' is not defined

# %%
df = pd.concat([df_object, df_number_log], axis=1)
df_test = pd.concat([df_test_object, df_test_number_log], axis=1)

# %%
df['gender'] = df['weight_class'].apply(lambda x: 'women' if 'women' in x.lower() else 'male')

# %%
df.head()
# Out:
#        weight_class  B_Stance  R_Stance  id  B_avg_KD  B_avg_opp_KD  \
# 0  WomenStrawweight  Orthodox  Orthodox   0       0.0          0.00
# 1      Welterweight  Orthodox  Orthodox   1       0.0          0.25
# 2     Featherweight  Orthodox  Orthodox   2       0.0          0.50
# 3      Bantamweight  Orthodox  Orthodox   3       0.0          0.00
# 4      Welterweight  Orthodox  Orthodox   4       0.0          0.00
#
#    B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  \
# 0           0.493750               0.448750      0.475000          0.177500
# 1           0.473125               0.371875      0.000000          0.203750
# 2           0.500000               0.480000      0.615000          0.000000
# 3           0.660000               0.690000      0.850000          0.000000
# 4           0.505312               0.439375      0.815937          0.067187
#
#    ...  R_win_by_Decision_Unanimous  R_win_by_KO/TKO  R_win_by_Submission  \
# 0  ...                            4                0                    0
# 1  ...                            1                2                    0
# 2  ...                            0                0                    0
# 3  ...                            0                0                    0
# 4  ...                            0                0                    1
#
#    R_win_by_TKO_Doctor_Stoppage  R_Height_cms  R_Reach_cms  R_Weight_lbs  \
# 0                             0        154.94       152.40         115.0
# 1                             0        170.18       182.88         170.0
# 2                             0        170.18       177.80         145.0
# 3                             0        165.10       162.56         125.0
# 4                             0        175.26       182.88         170.0
#
#    B_age  R_age  gender
# 0   35.0   27.0   women
# 1   28.0   31.0    male
# 2   24.0   30.0    male
# 3   27.0   23.0    male
# 4   33.0   24.0    male
#
# [5 rows x 138 columns]

# %%
df['weight_class'] = df['weight_class'].str.replace('Women', '')

# %%
# Get all weight_class values
weight_class = df['weight_class'].unique()
weight_class
# Out:
# array(['Strawweight', 'Welterweight', 'Featherweight', 'Bantamweight',
#        'Middleweight', 'Lightweight', 'LightHeavyweight', 'Heavyweight',
#        'CatchWeight', 'OpenWeight', 'Flyweight'], dtype=object)

# %%
# Create a dictionary to map weight_class values to numbers
weight_class_dict = {
    'CatchWeight' : 0,
    'Strawweight' : 1,
    'Flyweight' : 2,
    'Bantamweight' : 3,
    'Featherweight' : 4,
    'Lightweight' : 5,
    'Welterweight' : 6,
    'Middleweight' : 7,
    'LightHeavyweight' : 8,
    'Heavyweight' : 9,
    'OpenWeight' : 10,
}

gender_dict = {
    'male' : 1,
    'women' : 0
}

# %%
# Map each weight_class value to the correct number
df['weight_class'] = df['weight_class'].map(weight_class_dict)

# %%
# Map each gender value to the correct number
df['gender'] = df['gender'].map(gender_dict)

# %%
df.head()
# Out:
#    weight_class  B_Stance  R_Stance  id  B_avg_KD  B_avg_opp_KD  \
# 0             1  Orthodox  Orthodox   0       0.0          0.00
# 1             6  Orthodox  Orthodox   1       0.0          0.25
# 2             4  Orthodox  Orthodox   2       0.0          0.50
# 3             3  Orthodox  Orthodox   3       0.0          0.00
# 4             6  Orthodox  Orthodox   4       0.0          0.00
#
#    B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  \
# 0           0.493750               0.448750      0.475000          0.177500
# 1           0.473125               0.371875      0.000000          0.203750
# 2           0.500000               0.480000      0.615000          0.000000
# 3           0.660000               0.690000      0.850000          0.000000
# 4           0.505312               0.439375      0.815937          0.067187
#
#    ...  R_win_by_Decision_Unanimous  R_win_by_KO/TKO  R_win_by_Submission  \
# 0  ...                            4                0                    0
# 1  ...                            1                2                    0
# 2  ...                            0                0                    0
# 3  ...                            0                0                    0
# 4  ...                            0                0                    1
#
#    R_win_by_TKO_Doctor_Stoppage  R_Height_cms  R_Reach_cms  R_Weight_lbs  \
# 0                             0        154.94       152.40         115.0
# 1                             0        170.18       182.88         170.0
# 2                             0        170.18       177.80         145.0
# 3                             0        165.10       162.56         125.0
# 4                             0        175.26       182.88         170.0
#
#    B_age  R_age  gender
# 0   35.0   27.0       0
# 1   28.0   31.0       1
# 2   24.0   30.0       1
# 3   27.0   23.0       1
# 4   33.0   24.0       1
#
# [5 rows x 138 columns]

# %%
# Get the remaining object columns
df_object = df.select_dtypes(include='object')

# Perform one-hot encoding
df_encoded = pd.get_dummies(df_object)

# Combine the encoded columns with the original dataframe
df = pd.concat([df, df_encoded], axis=1)

# Drop the original object columns
df.drop(df_object.columns, axis=1, inplace=True)

df.head()
# Out:
#    weight_class  id  B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  \
# 0             1   0       0.0          0.00           0.493750
# 1             6   1       0.0          0.25           0.473125
# 2             4   2       0.0          0.50           0.500000
# 3             3   3       0.0          0.00           0.660000
# 4             6   4       0.0          0.00           0.505312
#
#    B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  \
# 0               0.448750      0.475000          0.177500        0.00000
# 1               0.371875      0.000000          0.203750        0.00000
# 2               0.480000      0.615000          0.000000        0.00000
# 3               0.690000      0.850000          0.000000        0.00000
# 4               0.439375      0.815937          0.067187        1.28125
#
#    B_avg_opp_SUB_ATT  ...  R_age  gender  B_Stance_Open Stance  \
# 0           0.125000  ...   27.0       0                 False
# 1           0.500000  ...   31.0       1                 False
# 2           0.000000  ...   30.0       1                 False
# 3           2.000000  ...   23.0       1                 False
# 4           0.640625  ...   24.0       1                 False
#
#    B_Stance_Orthodox  B_Stance_Southpaw  B_Stance_Switch  \
# 0               True              False            False
# 1               True              False            False
# 2               True              False            False
# 3               True              False            False
# 4               True              False            False
#
#    R_Stance_Open Stance  R_Stance_Orthodox  R_Stance_Southpaw  R_Stance_Switch
# 0                 False               True              False            False
# 1                 False               True              False            False
# 2                 False               True              False            False
# 3                 False               True              False            False
# 4                 False               True              False            False
#
# [5 rows x 144 columns]

# %%
# Get the remaining object columns
df_test_object = df_test.select_dtypes(include='object')

# Perform one-hot encoding
df_test_encoded = pd.get_dummies(df_test_object)

# Combine the encoded columns with the original dataframe
df_test = pd.concat([df_test, df_test_encoded], axis=1)

# Drop the original object columns
df_test.drop(df_test_object.columns, axis=1, inplace=True)

df_test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 # Get the remaining object columns
# ----> 2 df_test_object = df_test.select_dtypes(include='object')
#       4 # Perform one-hot encoding
#       5 df_test_encoded = pd.get_dummies(df_test_object)
#
# NameError: name 'df_test' is not defined

# %%
df.to_csv('../UFC_Pre_kombinasi6.csv', index=False)

# %%
from sklearn.feature_selection import SelectKBest, f_regression
# Perform feature selection using SelectKBest
selector = SelectKBest(k=25, score_func=f_regression)
X = df.drop('B_Reach_cms', axis=1) 
y = df['B_Reach_cms'] 
X_selected = selector.fit_transform(X, y)

# Get the selected feature names
selected_feature_names = X.columns[selector.get_support()]
print(selected_feature_names)
# Create a new dataframe with only the selected features
df_selected = pd.DataFrame(X_selected, columns=selected_feature_names)
df_selected.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[236], line 6
#       4 X = df.drop('B_Reach_cms', axis=1)
#       5 y = df['B_Reach_cms']
# ----> 6 X_selected = selector.fit_transform(X, y)
#       8 # Get the selected feature names
#       9 selected_feature_names = X.columns[selector.get_support()]
#
# File c:\Python311\Lib\site-packages\sklearn\utils\_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File c:\Python311\Lib\site-packages\sklearn\base.py:919, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     916     return self.fit(X, **fit_params).transform(X)
#     917 else:
#     918     # fit method of arity 2 (supervised transformation)
# --> 919     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Python311\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Python311\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:498, in _BaseFilter.fit(self, X, y)
#     480 @_fit_context(prefer_skip_nested_validation=True)
#     481 def fit(self, X, y):
#     482     """Run score function on (X, y) and get the appropriate features.
#     483
#     484     Parameters
#    (...)
#     496         Returns the instance itself.
#     497     """
# --> 498     X, y = self._validate_data(
#     499         X, y, accept_sparse=["csr", "csc"], multi_output=True
#     500     )
#     502     self._check_params(X, y)
#     503     score_func_ret = self.score_func(X, y)
#
# File c:\Python311\Lib\site-packages\sklearn\base.py:622, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     620         y = check_array(y, input_name="y", **check_y_params)
#     621     else:
# --> 622         X, y = check_X_y(X, y, **check_params)
#     623     out = X, y
#     625 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Python311\Lib\site-packages\sklearn\utils\validation.py:1146, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1141         estimator_name = _check_estimator_name(estimator)
#    1142     raise ValueError(
#    1143         f"{estimator_name} requires y to be passed, but the target y is None"
#    1144     )
# -> 1146 X = check_array(
#    1147     X,
#    1148     accept_sparse=accept_sparse,
#    1149     accept_large_sparse=accept_large_sparse,
#    1150     dtype=dtype,
#    1151     order=order,
#    1152     copy=copy,
#    1153     force_all_finite=force_all_finite,
#    1154     ensure_2d=ensure_2d,
#    1155     allow_nd=allow_nd,
#    1156     ensure_min_samples=ensure_min_samples,
#    1157     ensure_min_features=ensure_min_features,
#    1158     estimator=estimator,
#    1159     input_name="X",
#    1160 )
#    1162 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1164 check_consistent_length(X, y)
#
# File c:\Python311\Lib\site-packages\sklearn\utils\validation.py:836, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     831 if pandas_requires_conversion:
#     832     # pandas dataframe requires conversion earlier to handle extension dtypes with
#     833     # nans
#     834     # Use the original dtype for conversion if dtype is None
#     835     new_dtype = dtype_orig if dtype is None else dtype
# --> 836     array = array.astype(new_dtype)
#     837     # Since we converted here, we do not need to convert again later
#     838     dtype = None
#
# File c:\Python311\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File c:\Python311\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File c:\Python311\Lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Python311\Lib\site-packages\pandas\core\internals\blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File c:\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File c:\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or arr.dtype == object or dtype == object:
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'Red'

# %%
print(df.shape)
# Out:
# (5410, 146)

# %%
df_selected['B_Reach_cms'] = y

# %%
df_selected.to_csv('../Punya Andi/UFC_kombinasi6.csv', index=False)

# %%
df_test_id = df_test['id']
df_test = df_test.drop(columns=['id'])
df_test = df_test.reindex(columns=df_selected.columns, fill_value=0)
df_test = pd.concat([df_test_id, df_test], axis=1)

# %%
df_test.to_csv('../regression_kaggle/UFC_kombinasi6.csv', index=False)
