# %%
# import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from collections import Counter
from imblearn.over_sampling import RandomOverSampler, SMOTE, BorderlineSMOTE, SVMSMOTE, ADASYN
from imblearn.under_sampling import RandomUnderSampler, NearMiss, TomekLinks
from sklearn.model_selection import StratifiedKFold, cross_val_score, GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('dataframe/UFC_Test_Classif_X.csv')
df.head()
# Out:
#    id      R_fighter       B_fighter               Referee        date  \
# 0   0   Tecia Torres    Juliana Lima         Chris Tognoni  2017-07-07
# 1   1    John Howard   Lorenz Larkin             Herb Dean  2015-01-18
# 2   2  Kyle Bochniak  Jeremy Kennedy  Todd Ronald Anderson  2017-07-22
# 3   3     Yao Zhikui     Royston Wee        Steve Perceval  2014-08-23
# 4   4  Carlos Newton    Pat Miletich         John McCarthy  2001-05-04
#
#                          location  title_bout      weight_class  B_avg_KD  \
# 0          Las Vegas, Nevada, USA       False  WomenStrawweight       0.0
# 1      Boston, Massachusetts, USA       False      Welterweight       0.0
# 2        Uniondale, New York, USA       False     Featherweight       0.0
# 3                    Macau, China       False      Bantamweight       0.0
# 4  Atlantic City, New Jersey, USA        True      Welterweight       0.0
#
#    B_avg_opp_KD  ...  R_win_by_Decision_Unanimous  R_win_by_KO/TKO  \
# 0          0.00  ...                            4                0
# 1          0.25  ...                            1                2
# 2          0.50  ...                            0                0
# 3          0.00  ...                            0                0
# 4          0.00  ...                            0                0
#
#    R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_Stance  R_Height_cms  \
# 0                    0                             0  Orthodox        154.94
# 1                    0                             0  Orthodox        170.18
# 2                    0                             0  Orthodox        170.18
# 3                    0                             0  Orthodox        165.10
# 4                    1                             0  Orthodox        175.26
#
#    R_Reach_cms  R_Weight_lbs  B_age  R_age
# 0       152.40         115.0   35.0   27.0
# 1       182.88         170.0   28.0   31.0
# 2       177.80         145.0   24.0   30.0
# 3       162.56         125.0   27.0   23.0
# 4          NaN         170.0   33.0   24.0
#
# [5 rows x 143 columns]

# %%
# Split string and number
# Split dataframe into object type and number type
df_object = df.select_dtypes(include='object')
df_number = df.select_dtypes(include=np.number)

# %%
# Impute missing value using iterative imputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.tree import ExtraTreeRegressor

imputer = IterativeImputer(initial_strategy='median', random_state=42, estimator=ExtraTreeRegressor(random_state=42), max_iter=15)
df_imputed_number = imputer.fit_transform(df_number)
df_imputed_number = pd.DataFrame(df_imputed_number, columns=df_number.columns)
# Out:
# C:\Users\fadlan\AppData\Roaming\Python\Python311\site-packages\sklearn\impute\_iterative.py:800: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(

# %%
# Drop R_fighter, B_fighter, Referee, location, date
df_object = df_object.drop(['R_fighter', 'B_fighter', 'Referee', 'location', 'date'], axis=1)

# %%
# Combine df_object and df_imputed_number
df = pd.concat([df_object, df_imputed_number], axis=1)
df.head()
# Out:
#        weight_class  B_Stance  R_Stance   id  B_avg_KD  B_avg_opp_KD  \
# 0  WomenStrawweight  Orthodox  Orthodox  0.0       0.0          0.00
# 1      Welterweight  Orthodox  Orthodox  1.0       0.0          0.25
# 2     Featherweight  Orthodox  Orthodox  2.0       0.0          0.50
# 3      Bantamweight  Orthodox  Orthodox  3.0       0.0          0.00
# 4      Welterweight  Orthodox  Orthodox  4.0       0.0          0.00
#
#    B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  \
# 0           0.493750               0.448750      0.475000          0.177500
# 1           0.473125               0.371875      0.000000          0.203750
# 2           0.500000               0.480000      0.615000          0.000000
# 3           0.660000               0.690000      0.850000          0.000000
# 4           0.505312               0.439375      0.815937          0.067187
#
#    ...  R_win_by_Decision_Split  R_win_by_Decision_Unanimous  R_win_by_KO/TKO  \
# 0  ...                      0.0                          4.0              0.0
# 1  ...                      3.0                          1.0              2.0
# 2  ...                      1.0                          0.0              0.0
# 3  ...                      0.0                          0.0              0.0
# 4  ...                      0.0                          0.0              0.0
#
#    R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_Height_cms  \
# 0                  0.0                           0.0        154.94
# 1                  0.0                           0.0        170.18
# 2                  0.0                           0.0        170.18
# 3                  0.0                           0.0        165.10
# 4                  1.0                           0.0        175.26
#
#    R_Reach_cms  R_Weight_lbs  B_age  R_age
# 0       152.40         115.0   35.0   27.0
# 1       182.88         170.0   28.0   31.0
# 2       177.80         145.0   24.0   30.0
# 3       162.56         125.0   27.0   23.0
# 4       182.88         170.0   33.0   24.0
#
# [5 rows x 137 columns]

# %%
# Impute missing R_stance and B_stance with mode
df['R_Stance'].fillna(df['R_Stance'].mode()[0], inplace=True)
df['B_Stance'].fillna(df['B_Stance'].mode()[0], inplace=True)

# %%
def check_outlier(df):
    Q1 = df.quantile(0.25)
    Q3 = df.quantile(0.75)

    # Menghitung RUB dan RLB.
    IQR = Q3 - Q1
    lower_limit = Q1 - 1.5*IQR
    upper_limit = Q3 + 1.5*IQR

    # Menampilkan banyaknya outlier pada atribut.
    outliers = (df < lower_limit) | (df > upper_limit)
    print ("Outlier pada tiap atribut:")
    print(outliers.sum())

    return outliers

# %%
# Split string and number
# Split dataframe into object type and number type
df_object = df.select_dtypes(include='object')
df_number = df.select_dtypes(include=np.number)

# %%
outliers = dict(check_outlier(df_number).sum())
print("\n\npercentage of outliers in each column:")
for key in outliers.keys():
    print(f"{key} = {outliers[key]/df_number[key].shape[0] * 100}%")
# Out:
# Outlier pada tiap atribut:
# id                         0
# B_avg_KD                  10
# B_avg_opp_KD             108
# B_avg_SIG_STR_pct         21
# B_avg_opp_SIG_STR_pct     15
#                         ...
# R_Height_cms               3
# R_Reach_cms               12
# R_Weight_lbs              32
# B_age                     11
# R_age                      1
# Length: 134, dtype: int64
#
#
# percentage of outliers in each column:
# id = 0.0%
# B_avg_KD = 1.6611295681063125%
# B_avg_opp_KD = 17.940199335548172%
# B_avg_SIG_STR_pct = 3.488372093023256%
# B_avg_opp_SIG_STR_pct = 2.4916943521594686%
# B_avg_TD_pct = 0.0%
# B_avg_opp_TD_pct = 0.0%
# B_avg_SUB_ATT = 6.976744186046512%
# B_avg_opp_SUB_ATT = 4.152823920265781%
# B_avg_REV = 17.441860465116278%
# B_avg_opp_REV = 20.59800664451827%
# B_avg_SIG_STR_att = 2.990033222591362%
# B_avg_SIG_STR_landed = 3.322259136212625%
# B_avg_opp_SIG_STR_att = 2.6578073089700998%
# B_avg_opp_SIG_STR_landed = 2.3255813953488373%
# B_avg_TOTAL_STR_att = 2.1594684385382057%
# B_avg_TOTAL_STR_landed = 1.495016611295681%
# B_avg_opp_TOTAL_STR_att = 2.1594684385382057%
# B_avg_opp_TOTAL_STR_landed = 2.6578073089700998%
# B_avg_TD_att = 4.485049833887043%
# B_avg_TD_landed = 5.48172757475083%
# B_avg_opp_TD_att = 3.6544850498338874%
# B_avg_opp_TD_landed = 5.980066445182724%
# B_avg_HEAD_att = 2.823920265780731%
# B_avg_HEAD_landed = 3.322259136212625%
# B_avg_opp_HEAD_att = 2.823920265780731%
# B_avg_opp_HEAD_landed = 2.990033222591362%
# B_avg_BODY_att = 5.980066445182724%
# B_avg_BODY_landed = 4.817275747508306%
# B_avg_opp_BODY_att = 3.322259136212625%
# B_avg_opp_BODY_landed = 3.1561461794019934%
# B_avg_LEG_att = 5.980066445182724%
# B_avg_LEG_landed = 5.813953488372093%
# B_avg_opp_LEG_att = 3.9867109634551494%
# B_avg_opp_LEG_landed = 5.980066445182724%
# B_avg_DISTANCE_att = 3.322259136212625%
# B_avg_DISTANCE_landed = 3.488372093023256%
# B_avg_opp_DISTANCE_att = 2.990033222591362%
# B_avg_opp_DISTANCE_landed = 3.322259136212625%
# B_avg_CLINCH_att = 5.149501661129568%
# B_avg_CLINCH_landed = 5.813953488372093%
# B_avg_opp_CLINCH_att = 3.9867109634551494%
# B_avg_opp_CLINCH_landed = 2.4916943521594686%
# B_avg_GROUND_att = 2.990033222591362%
# B_avg_GROUND_landed = 3.6544850498338874%
# B_avg_opp_GROUND_att = 5.980066445182724%
# B_avg_opp_GROUND_landed = 6.64451827242525%
# B_avg_CTRL_time(seconds) = 4.651162790697675%
# B_avg_opp_CTRL_time(seconds) = 5.149501661129568%
# B_total_time_fought(seconds) = 0.0%
# B_total_rounds_fought = 5.149501661129568%
# B_total_title_bouts = 12.29235880398671%
# B_current_win_streak = 9.966777408637874%
# B_current_lose_streak = 1.3289036544850499%
# B_longest_win_streak = 2.823920265780731%
# B_wins = 3.488372093023256%
# B_losses = 5.48172757475083%
# B_draw = 0.0%
# B_win_by_Decision_Majority = 0.9966777408637874%
# B_win_by_Decision_Split = 17.109634551495017%
# B_win_by_Decision_Unanimous = 11.295681063122924%
# B_win_by_KO/TKO = 11.794019933554816%
# B_win_by_Submission = 5.3156146179401995%
# B_win_by_TKO_Doctor_Stoppage = 3.6544850498338874%
# B_Height_cms = 0.33222591362126247%
# B_Weight_lbs = 4.318936877076411%
# R_avg_KD = 7.475083056478406%
# R_avg_opp_KD = 6.4784053156146175%
# R_avg_SIG_STR_pct = 2.990033222591362%
# R_avg_opp_SIG_STR_pct = 2.1594684385382057%
# R_avg_TD_pct = 0.0%
# R_avg_opp_TD_pct = 0.0%
# R_avg_SUB_ATT = 7.475083056478406%
# R_avg_opp_SUB_ATT = 6.312292358803987%
# R_avg_REV = 18.6046511627907%
# R_avg_opp_REV = 15.946843853820598%
# R_avg_SIG_STR_att = 3.1561461794019934%
# R_avg_SIG_STR_landed = 2.823920265780731%
# R_avg_opp_SIG_STR_att = 2.1594684385382057%
# R_avg_opp_SIG_STR_landed = 2.4916943521594686%
# R_avg_TOTAL_STR_att = 2.6578073089700998%
# R_avg_TOTAL_STR_landed = 3.1561461794019934%
# R_avg_opp_TOTAL_STR_att = 1.9933554817275747%
# R_avg_opp_TOTAL_STR_landed = 2.6578073089700998%
# R_avg_TD_att = 3.9867109634551494%
# R_avg_TD_landed = 3.820598006644518%
# R_avg_opp_TD_att = 4.318936877076411%
# R_avg_opp_TD_landed = 4.485049833887043%
# R_avg_HEAD_att = 3.322259136212625%
# R_avg_HEAD_landed = 4.485049833887043%
# R_avg_opp_HEAD_att = 2.6578073089700998%
# R_avg_opp_HEAD_landed = 3.1561461794019934%
# R_avg_BODY_att = 5.149501661129568%
# R_avg_BODY_landed = 5.813953488372093%
# R_avg_opp_BODY_att = 2.6578073089700998%
# R_avg_opp_BODY_landed = 3.488372093023256%
# R_avg_LEG_att = 2.990033222591362%
# R_avg_LEG_landed = 2.6578073089700998%
# R_avg_opp_LEG_att = 4.651162790697675%
# R_avg_opp_LEG_landed = 3.488372093023256%
# R_avg_DISTANCE_att = 2.990033222591362%
# R_avg_DISTANCE_landed = 2.4916943521594686%
# R_avg_opp_DISTANCE_att = 2.3255813953488373%
# R_avg_opp_DISTANCE_landed = 1.8272425249169437%
# R_avg_CLINCH_att = 4.318936877076411%
# R_avg_CLINCH_landed = 5.3156146179401995%
# R_avg_opp_CLINCH_att = 4.651162790697675%
# R_avg_opp_CLINCH_landed = 6.312292358803987%
# R_avg_GROUND_att = 4.817275747508306%
# R_avg_GROUND_landed = 6.810631229235881%
# R_avg_opp_GROUND_att = 7.807308970099667%
# R_avg_opp_GROUND_landed = 7.308970099667775%
# R_avg_CTRL_time(seconds) = 2.6578073089700998%
# R_avg_opp_CTRL_time(seconds) = 3.820598006644518%
# R_total_time_fought(seconds) = 0.33222591362126247%
# R_total_rounds_fought = 7.641196013289036%
# R_total_title_bouts = 23.421926910299003%
# R_current_win_streak = 2.990033222591362%
# R_current_lose_streak = 0.9966777408637874%
# R_longest_win_streak = 4.983388704318937%
# R_wins = 5.813953488372093%
# R_losses = 4.485049833887043%
# R_draw = 0.0%
# R_win_by_Decision_Majority = 2.990033222591362%
# R_win_by_Decision_Split = 24.418604651162788%
# R_win_by_Decision_Unanimous = 3.9867109634551494%
# R_win_by_KO/TKO = 3.9867109634551494%
# R_win_by_Submission = 8.305647840531561%
# R_win_by_TKO_Doctor_Stoppage = 7.142857142857142%
# R_Height_cms = 0.4983388704318937%
# R_Reach_cms = 1.9933554817275747%
# R_Weight_lbs = 5.3156146179401995%
# B_age = 1.8272425249169437%
# R_age = 0.16611295681063123%

# %%
from scipy.stats.mstats import winsorize

from scipy.stats.mstats import winsorize

# Identify columns with more than 0.5% outliers
outlier_columns = []
for key in outliers.keys():
    if outliers[key] / df_number[key].shape[0] > 0.005:
        outlier_columns.append(key)

# Winsorize the identified columns
for column in outlier_columns:
    df_number[column] = winsorize(df_number[column], limits=(0, 0.1))

# Combine df_object and df_number
df = pd.concat([df_object, df_number], axis=1)
df.head()
# Out:
#        weight_class  B_Stance  R_Stance   id  B_avg_KD  B_avg_opp_KD  \
# 0  WomenStrawweight  Orthodox  Orthodox  0.0       0.0          0.00
# 1      Welterweight  Orthodox  Orthodox  1.0       0.0          0.25
# 2     Featherweight  Orthodox  Orthodox  2.0       0.0          0.50
# 3      Bantamweight  Orthodox  Orthodox  3.0       0.0          0.00
# 4      Welterweight  Orthodox  Orthodox  4.0       0.0          0.00
#
#    B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  \
# 0           0.493750               0.448750      0.475000          0.177500
# 1           0.473125               0.371875      0.000000          0.203750
# 2           0.500000               0.480000      0.615000          0.000000
# 3           0.615000               0.605000      0.850000          0.000000
# 4           0.505312               0.439375      0.815937          0.067187
#
#    ...  R_win_by_Decision_Split  R_win_by_Decision_Unanimous  R_win_by_KO/TKO  \
# 0  ...                      0.0                          4.0              0.0
# 1  ...                      1.0                          1.0              2.0
# 2  ...                      1.0                          0.0              0.0
# 3  ...                      0.0                          0.0              0.0
# 4  ...                      0.0                          0.0              0.0
#
#    R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_Height_cms  \
# 0                  0.0                           0.0        154.94
# 1                  0.0                           0.0        170.18
# 2                  0.0                           0.0        170.18
# 3                  0.0                           0.0        165.10
# 4                  1.0                           0.0        175.26
#
#    R_Reach_cms  R_Weight_lbs  B_age  R_age
# 0       152.40         115.0   35.0   27.0
# 1       182.88         170.0   28.0   31.0
# 2       177.80         145.0   24.0   30.0
# 3       162.56         125.0   27.0   23.0
# 4       182.88         170.0   33.0   24.0
#
# [5 rows x 137 columns]

# %%
outliers = dict(check_outlier(df_number).sum())
print("\n\npercentage of outliers in each column:")
for key in outliers.keys():
    print(f"{key} = {outliers[key]/df_number[key].shape[0] * 100}%")
# Out:
# C:\Users\fadlan\AppData\Roaming\Python\Python311\site-packages\numpy\lib\function_base.py:4823: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# C:\Users\fadlan\AppData\Roaming\Python\Python311\site-packages\numpy\lib\function_base.py:4823: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# Outlier pada tiap atribut:
# id                         0
# B_avg_KD                   0
# B_avg_opp_KD             108
# B_avg_SIG_STR_pct          8
# B_avg_opp_SIG_STR_pct      4
#                         ...
# R_Height_cms               3
# R_Reach_cms                6
# R_Weight_lbs               0
# B_age                      0
# R_age                      1
# Length: 134, dtype: int64
#
#
# percentage of outliers in each column:
# id = 0.0%
# B_avg_KD = 0.0%
# B_avg_opp_KD = 17.940199335548172%
# B_avg_SIG_STR_pct = 1.3289036544850499%
# B_avg_opp_SIG_STR_pct = 0.6644518272425249%
# B_avg_TD_pct = 0.0%
# B_avg_opp_TD_pct = 0.0%
# B_avg_SUB_ATT = 0.0%
# B_avg_opp_SUB_ATT = 0.0%
# B_avg_REV = 17.441860465116278%
# B_avg_opp_REV = 20.59800664451827%
# B_avg_SIG_STR_att = 0.0%
# B_avg_SIG_STR_landed = 0.0%
# B_avg_opp_SIG_STR_att = 0.0%
# B_avg_opp_SIG_STR_landed = 0.0%
# B_avg_TOTAL_STR_att = 0.0%
# B_avg_TOTAL_STR_landed = 0.0%
# B_avg_opp_TOTAL_STR_att = 0.0%
# B_avg_opp_TOTAL_STR_landed = 0.0%
# B_avg_TD_att = 0.0%
# B_avg_TD_landed = 0.0%
# B_avg_opp_TD_att = 0.0%
# B_avg_opp_TD_landed = 0.0%
# B_avg_HEAD_att = 0.0%
# B_avg_HEAD_landed = 0.0%
# B_avg_opp_HEAD_att = 0.0%
# B_avg_opp_HEAD_landed = 0.0%
# B_avg_BODY_att = 0.0%
# B_avg_BODY_landed = 0.0%
# B_avg_opp_BODY_att = 0.0%
# B_avg_opp_BODY_landed = 0.0%
# B_avg_LEG_att = 0.0%
# B_avg_LEG_landed = 0.0%
# B_avg_opp_LEG_att = 0.0%
# B_avg_opp_LEG_landed = 0.0%
# B_avg_DISTANCE_att = 0.0%
# B_avg_DISTANCE_landed = 0.0%
# B_avg_opp_DISTANCE_att = 0.0%
# B_avg_opp_DISTANCE_landed = 0.0%
# B_avg_CLINCH_att = 0.0%
# B_avg_CLINCH_landed = 0.0%
# B_avg_opp_CLINCH_att = 0.0%
# B_avg_opp_CLINCH_landed = 0.0%
# B_avg_GROUND_att = 0.0%
# B_avg_GROUND_landed = 0.0%
# B_avg_opp_GROUND_att = 0.0%
# B_avg_opp_GROUND_landed = 0.0%
# B_avg_CTRL_time(seconds) = 0.0%
# B_avg_opp_CTRL_time(seconds) = 0.0%
# B_total_time_fought(seconds) = 0.0%
# B_total_rounds_fought = 0.0%
# B_total_title_bouts = 12.29235880398671%
# B_current_win_streak = 0.0%
# B_current_lose_streak = 0.0%
# B_longest_win_streak = 0.0%
# B_wins = 0.0%
# B_losses = 0.0%
# B_draw = 0.0%
# B_win_by_Decision_Majority = 0.0%
# B_win_by_Decision_Split = 17.109634551495017%
# B_win_by_Decision_Unanimous = 11.295681063122924%
# B_win_by_KO/TKO = 11.794019933554816%
# B_win_by_Submission = 0.0%
# B_win_by_TKO_Doctor_Stoppage = 0.0%
# B_Height_cms = 0.33222591362126247%
# B_Weight_lbs = 0.0%
# R_avg_KD = 0.0%
# R_avg_opp_KD = 0.0%
# R_avg_SIG_STR_pct = 0.9966777408637874%
# R_avg_opp_SIG_STR_pct = 0.9966777408637874%
# R_avg_TD_pct = 0.0%
# R_avg_opp_TD_pct = 0.0%
# R_avg_SUB_ATT = 0.0%
# R_avg_opp_SUB_ATT = 0.0%
# R_avg_REV = 18.6046511627907%
# R_avg_opp_REV = 15.946843853820598%
# R_avg_SIG_STR_att = 0.0%
# R_avg_SIG_STR_landed = 0.0%
# R_avg_opp_SIG_STR_att = 0.0%
# R_avg_opp_SIG_STR_landed = 0.0%
# R_avg_TOTAL_STR_att = 0.0%
# R_avg_TOTAL_STR_landed = 0.0%
# R_avg_opp_TOTAL_STR_att = 0.0%
# R_avg_opp_TOTAL_STR_landed = 0.0%
# R_avg_TD_att = 0.0%
# R_avg_TD_landed = 0.0%
# R_avg_opp_TD_att = 0.0%
# R_avg_opp_TD_landed = 0.0%
# R_avg_HEAD_att = 0.0%
# R_avg_HEAD_landed = 0.0%
# R_avg_opp_HEAD_att = 0.0%
# R_avg_opp_HEAD_landed = 0.0%
# R_avg_BODY_att = 0.0%
# R_avg_BODY_landed = 0.0%
# R_avg_opp_BODY_att = 0.0%
# R_avg_opp_BODY_landed = 0.0%
# R_avg_LEG_att = 0.0%
# R_avg_LEG_landed = 0.0%
# R_avg_opp_LEG_att = 0.0%
# R_avg_opp_LEG_landed = 0.0%
# R_avg_DISTANCE_att = 0.0%
# R_avg_DISTANCE_landed = 0.0%
# R_avg_opp_DISTANCE_att = 0.0%
# R_avg_opp_DISTANCE_landed = 0.0%
# R_avg_CLINCH_att = 0.0%
# R_avg_CLINCH_landed = 0.0%
# R_avg_opp_CLINCH_att = 0.0%
# R_avg_opp_CLINCH_landed = 0.0%
# R_avg_GROUND_att = 0.0%
# R_avg_GROUND_landed = 0.0%
# R_avg_opp_GROUND_att = 0.0%
# R_avg_opp_GROUND_landed = 0.0%
# R_avg_CTRL_time(seconds) = 0.0%
# R_avg_opp_CTRL_time(seconds) = 0.0%
# R_total_time_fought(seconds) = 0.33222591362126247%
# R_total_rounds_fought = 0.0%
# R_total_title_bouts = 23.421926910299003%
# R_current_win_streak = 0.0%
# R_current_lose_streak = 0.0%
# R_longest_win_streak = 0.0%
# R_wins = 0.0%
# R_losses = 0.0%
# R_draw = 0.0%
# R_win_by_Decision_Majority = 0.0%
# R_win_by_Decision_Split = 24.418604651162788%
# R_win_by_Decision_Unanimous = 0.0%
# R_win_by_KO/TKO = 0.0%
# R_win_by_Submission = 0.0%
# R_win_by_TKO_Doctor_Stoppage = 0.0%
# R_Height_cms = 0.4983388704318937%
# R_Reach_cms = 0.9966777408637874%
# R_Weight_lbs = 0.0%
# B_age = 0.0%
# R_age = 0.16611295681063123%

# %%
df['gender'] = df['weight_class'].apply(lambda x: 'women' if 'women' in x.lower() else 'male')

# %%
df['weight_class'] = df['weight_class'].str.replace('Women', '')

# %%
# Get all weight_class values
weight_class = df['weight_class'].unique()
weight_class
# Out:
# array(['Strawweight', 'Welterweight', 'Featherweight', 'Bantamweight',
#        'Middleweight', 'Lightweight', 'LightHeavyweight', 'Heavyweight',
#        'CatchWeight', 'OpenWeight', 'Flyweight'], dtype=object)

# %%
# Create a dictionary to map weight_class values to numbers
weight_class_dict = {
    'CatchWeight' : 0,
    'Strawweight' : 1,
    'Flyweight' : 2,
    'Bantamweight' : 3,
    'Featherweight' : 4,
    'Lightweight' : 5,
    'Welterweight' : 6,
    'Middleweight' : 7,
    'LightHeavyweight' : 8,
    'Heavyweight' : 9,
    'OpenWeight' : 10,
}

gender_dict = {
    'male' : 1,
    'women' : 0
}

# %%
# Map each weight_class value to the correct number
df['weight_class'] = df['weight_class'].map(weight_class_dict)

# %%
# Map each gender value to the correct number
df['gender'] = df['gender'].map(gender_dict)

# %%
df.head()
# Out:
#    weight_class  B_Stance  R_Stance   id  B_avg_KD  B_avg_opp_KD  \
# 0             1  Orthodox  Orthodox  0.0       0.0          0.00
# 1             6  Orthodox  Orthodox  1.0       0.0          0.25
# 2             4  Orthodox  Orthodox  2.0       0.0          0.50
# 3             3  Orthodox  Orthodox  3.0       0.0          0.00
# 4             6  Orthodox  Orthodox  4.0       0.0          0.00
#
#    B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  \
# 0           0.493750               0.448750      0.475000          0.177500
# 1           0.473125               0.371875      0.000000          0.203750
# 2           0.500000               0.480000      0.615000          0.000000
# 3           0.615000               0.605000      0.850000          0.000000
# 4           0.505312               0.439375      0.815937          0.067187
#
#    ...  R_win_by_Decision_Unanimous  R_win_by_KO/TKO  R_win_by_Submission  \
# 0  ...                          4.0              0.0                  0.0
# 1  ...                          1.0              2.0                  0.0
# 2  ...                          0.0              0.0                  0.0
# 3  ...                          0.0              0.0                  0.0
# 4  ...                          0.0              0.0                  1.0
#
#    R_win_by_TKO_Doctor_Stoppage  R_Height_cms  R_Reach_cms  R_Weight_lbs  \
# 0                           0.0        154.94       152.40         115.0
# 1                           0.0        170.18       182.88         170.0
# 2                           0.0        170.18       177.80         145.0
# 3                           0.0        165.10       162.56         125.0
# 4                           0.0        175.26       182.88         170.0
#
#    B_age  R_age  gender
# 0   35.0   27.0       0
# 1   28.0   31.0       1
# 2   24.0   30.0       1
# 3   27.0   23.0       1
# 4   33.0   24.0       1
#
# [5 rows x 138 columns]

# %%
# Get the remaining object columns
df_object = df.select_dtypes(include='object')

# Perform one-hot encoding
df_encoded = pd.get_dummies(df_object)

# Combine the encoded columns with the original dataframe
df = pd.concat([df, df_encoded], axis=1)

# Drop the original object columns
df.drop(df_object.columns, axis=1, inplace=True)

df.head()
# Out:
#    weight_class   id  B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  \
# 0             1  0.0       0.0          0.00           0.493750
# 1             6  1.0       0.0          0.25           0.473125
# 2             4  2.0       0.0          0.50           0.500000
# 3             3  3.0       0.0          0.00           0.615000
# 4             6  4.0       0.0          0.00           0.505312
#
#    B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  \
# 0               0.448750      0.475000          0.177500           0.00
# 1               0.371875      0.000000          0.203750           0.00
# 2               0.480000      0.615000          0.000000           0.00
# 3               0.605000      0.850000          0.000000           0.00
# 4               0.439375      0.815937          0.067187           1.25
#
#    B_avg_opp_SUB_ATT  ...  R_age  gender  B_Stance_Open Stance  \
# 0           0.125000  ...   27.0       0                 False
# 1           0.500000  ...   31.0       1                 False
# 2           0.000000  ...   30.0       1                 False
# 3           1.062500  ...   23.0       1                 False
# 4           0.640625  ...   24.0       1                 False
#
#    B_Stance_Orthodox  B_Stance_Southpaw  B_Stance_Switch  \
# 0               True              False            False
# 1               True              False            False
# 2               True              False            False
# 3               True              False            False
# 4               True              False            False
#
#    R_Stance_Open Stance  R_Stance_Orthodox  R_Stance_Southpaw  R_Stance_Switch
# 0                 False               True              False            False
# 1                 False               True              False            False
# 2                 False               True              False            False
# 3                 False               True              False            False
# 4                 False               True              False            False
#
# [5 rows x 144 columns]

# %%
df = df[['B_avg_DISTANCE_landed', 'R_avg_opp_SIG_STR_pct', 'R_age',
       'B_avg_CTRL_time(seconds)', 'B_avg_opp_SIG_STR_pct', 'B_avg_HEAD_att',
       'B_avg_opp_LEG_att', 'B_age', 'B_avg_DISTANCE_att', 'R_losses',
       'R_avg_opp_HEAD_landed', 'R_avg_opp_LEG_att', 'R_avg_LEG_att',
       'B_avg_GROUND_att', 'R_avg_GROUND_landed', 'R_avg_opp_BODY_landed',
       'R_avg_SUB_ATT', 'R_avg_opp_DISTANCE_att', 'R_avg_BODY_landed',
       'R_avg_opp_CTRL_time(seconds)']]

df.head()
# Out:
#    B_avg_DISTANCE_landed  R_avg_opp_SIG_STR_pct  R_age  \
# 0               17.68750               0.266250   27.0
# 1               16.06250               0.536279   31.0
# 2               14.00000               0.360000   30.0
# 3                0.00000               0.400000   23.0
# 4                5.71875               0.330000   24.0
#
#    B_avg_CTRL_time(seconds)  B_avg_opp_SIG_STR_pct  B_avg_HEAD_att  \
# 0                  349.5000               0.448750         60.3125
# 1                    9.6875               0.371875         37.1250
# 2                  349.5000               0.480000         61.0000
# 3                  349.5000               0.605000         11.0000
# 4                  219.7500               0.439375         24.2500
#
#    B_avg_opp_LEG_att  B_age  B_avg_DISTANCE_att  R_losses  \
# 0           0.625000   35.0           58.125000       1.0
# 1           8.125000   28.0           42.687500       5.0
# 2           4.000000   24.0           40.000000       1.0
# 3           4.000000   27.0            2.000000       0.0
# 4           3.046875   33.0           18.984375       1.0
#
#    R_avg_opp_HEAD_landed  R_avg_opp_LEG_att  R_avg_LEG_att  B_avg_GROUND_att  \
# 0              20.562500           4.937500      15.211609         12.875000
# 1              22.541016          14.312500      13.258789          0.125000
# 2              41.500000          14.312500      15.211609         19.000000
# 3              30.218750           5.632935       2.687500          9.000000
# 4              13.000000           0.000000       4.500000          7.703125
#
#    R_avg_GROUND_landed  R_avg_opp_BODY_landed  R_avg_SUB_ATT  \
# 0             1.937500              13.187500       0.000000
# 1             1.556641              13.320312       0.073242
# 2             1.000000              13.320312       0.000000
# 3            11.000000              11.000000       0.000000
# 4             0.500000               1.000000       1.125000
#
#    R_avg_opp_DISTANCE_att  R_avg_BODY_landed  R_avg_opp_CTRL_time(seconds)
# 0              126.812500          13.562500                     94.937500
# 1               67.904297           8.336914                    273.668945
# 2              126.812500           5.000000                     40.500000
# 3              126.812500           6.000000                     37.281250
# 4                5.000000           1.000000                      0.000000

# %%
df.to_csv('dataframe/UFC_kombinasi3_kaggle.csv', index=False)
