# %% [markdown]
# ### Kombinasi 8 :
# * Delete Duplicate
# * Delete Null
# * Outlier capping pake log
# * Encoding
# * Standard scaler
# * Feature selection -> K-Best

# %%
# import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("dataframe/UFC_Test_Classif_X.csv")
df.head()
# Out:
#    id      R_fighter       B_fighter               Referee        date  \
# 0   0   Tecia Torres    Juliana Lima         Chris Tognoni  2017-07-07
# 1   1    John Howard   Lorenz Larkin             Herb Dean  2015-01-18
# 2   2  Kyle Bochniak  Jeremy Kennedy  Todd Ronald Anderson  2017-07-22
# 3   3     Yao Zhikui     Royston Wee        Steve Perceval  2014-08-23
# 4   4  Carlos Newton    Pat Miletich         John McCarthy  2001-05-04
#
#                          location  title_bout      weight_class  B_avg_KD  \
# 0          Las Vegas, Nevada, USA       False  WomenStrawweight       0.0
# 1      Boston, Massachusetts, USA       False      Welterweight       0.0
# 2        Uniondale, New York, USA       False     Featherweight       0.0
# 3                    Macau, China       False      Bantamweight       0.0
# 4  Atlantic City, New Jersey, USA        True      Welterweight       0.0
#
#    B_avg_opp_KD  ...  R_win_by_Decision_Unanimous  R_win_by_KO/TKO  \
# 0          0.00  ...                            4                0
# 1          0.25  ...                            1                2
# 2          0.50  ...                            0                0
# 3          0.00  ...                            0                0
# 4          0.00  ...                            0                0
#
#    R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_Stance  R_Height_cms  \
# 0                    0                             0  Orthodox        154.94
# 1                    0                             0  Orthodox        170.18
# 2                    0                             0  Orthodox        170.18
# 3                    0                             0  Orthodox        165.10
# 4                    1                             0  Orthodox        175.26
#
#    R_Reach_cms  R_Weight_lbs  B_age  R_age
# 0       152.40         115.0   35.0   27.0
# 1       182.88         170.0   28.0   31.0
# 2       177.80         145.0   24.0   30.0
# 3       162.56         125.0   27.0   23.0
# 4          NaN         170.0   33.0   24.0
#
# [5 rows x 143 columns]

# %%
# Delete duplicate
print(f"Shape before dropping duplicates : {df.shape}") # Before dropping duplicates
df.drop_duplicates(inplace=True)
print(f"Shape after dropping duplicates: {df.shape}") # After dropping duplicates
# Out:
# Shape before dropping duplicates : (602, 143)
# Shape after dropping duplicates: (602, 143)

# %%
def check_null(df):
    col_na = df.isnull().sum().sort_values(ascending=True)
    percent = col_na / len(df)
    missing_data = pd.concat([col_na, percent], axis=1, keys=['Total', 'Percent'])

    if (missing_data[missing_data['Total'] > 0].shape[0] == 0):
        print("Tidak ditemukan missing value pada dataset")
    else:
        print(missing_data[missing_data['Total'] > 0])

# %%
check_null(df)
# Out:
#                           Total   Percent
# Referee                       1  0.001661
# R_Stance                      2  0.003322
# B_Stance                      2  0.003322
# R_age                         7  0.011628
# B_age                        11  0.018272
# ...                         ...       ...
# B_avg_CTRL_time(seconds)    134  0.222591
# B_avg_opp_GROUND_att        134  0.222591
# B_avg_GROUND_landed         134  0.222591
# B_avg_BODY_landed           134  0.222591
# B_avg_DISTANCE_att          134  0.222591
#
# [104 rows x 2 columns]

# %%
df.dropna(inplace=True)

# %%
check_null(df)
# Out:
# Tidak ditemukan missing value pada dataset

# %%
# Drop R_fighter, B_fighter, Referee, location, and date
df = df.drop(['R_fighter', 'B_fighter', 'Referee', 'location', 'date'], axis=1)

# %%
check_null(df)
# Out:
# Tidak ditemukan missing value pada dataset

# %%
check_null(df)
# Out:
# Tidak ditemukan missing value pada dataset

# %%
# Impute missing R_stance and B_stance with mode
df['R_Stance'].fillna(df['R_Stance'].mode()[0], inplace=True)
df['B_Stance'].fillna(df['B_Stance'].mode()[0], inplace=True)

# %%
check_null(df)
# Out:
# Tidak ditemukan missing value pada dataset

# %%
def check_outlier(df):
    Q1 = df.quantile(0.25)
    Q3 = df.quantile(0.75)

    # Menghitung RUB dan RLB.
    IQR = Q3 - Q1
    lower_limit = Q1 - 1.5*IQR
    upper_limit = Q3 + 1.5*IQR

    # Menampilkan banyaknya outlier pada atribut.
    outliers = (df < lower_limit) | (df > upper_limit)
    print ("Outlier pada tiap atribut:")
    print(outliers.sum())

    return outliers

# %%
# Split string and number
# Split dataframe into object type and number type
df_object = df.select_dtypes(include='object')
df_number = df.select_dtypes(include=np.number)

# %%
outliers = dict(check_outlier(df_number).sum())
print("\n\npercentage of outliers in each column:")
for key in outliers.keys():
    print(f"{key} = {outliers[key]/df_number[key].shape[0] * 100}%")
# Out:
# Outlier pada tiap atribut:
# id                        0
# B_avg_KD                  7
# B_avg_opp_KD             25
# B_avg_SIG_STR_pct        13
# B_avg_opp_SIG_STR_pct    10
#                          ..
# R_Height_cms              3
# R_Reach_cms              11
# R_Weight_lbs             20
# B_age                     2
# R_age                     1
# Length: 134, dtype: int64
#
#
# percentage of outliers in each column:
# id = 0.0%
# B_avg_KD = 1.6203703703703702%
# B_avg_opp_KD = 5.787037037037037%
# B_avg_SIG_STR_pct = 3.009259259259259%
# B_avg_opp_SIG_STR_pct = 2.314814814814815%
# B_avg_TD_pct = 0.0%
# B_avg_opp_TD_pct = 3.7037037037037033%
# B_avg_SUB_ATT = 6.481481481481481%
# B_avg_opp_SUB_ATT = 6.944444444444445%
# B_avg_REV = 17.12962962962963%
# B_avg_opp_REV = 19.90740740740741%
# B_avg_SIG_STR_att = 2.083333333333333%
# B_avg_SIG_STR_landed = 2.5462962962962963%
# B_avg_opp_SIG_STR_att = 1.8518518518518516%
# B_avg_opp_SIG_STR_landed = 2.314814814814815%
# B_avg_TOTAL_STR_att = 1.6203703703703702%
# B_avg_TOTAL_STR_landed = 2.083333333333333%
# B_avg_opp_TOTAL_STR_att = 2.314814814814815%
# B_avg_opp_TOTAL_STR_landed = 2.5462962962962963%
# B_avg_TD_att = 3.7037037037037033%
# B_avg_TD_landed = 3.935185185185185%
# B_avg_opp_TD_att = 4.166666666666666%
# B_avg_opp_TD_landed = 5.324074074074074%
# B_avg_HEAD_att = 2.083333333333333%
# B_avg_HEAD_landed = 3.009259259259259%
# B_avg_opp_HEAD_att = 2.083333333333333%
# B_avg_opp_HEAD_landed = 2.7777777777777777%
# B_avg_BODY_att = 3.935185185185185%
# B_avg_BODY_landed = 5.092592592592593%
# B_avg_opp_BODY_att = 2.5462962962962963%
# B_avg_opp_BODY_landed = 3.7037037037037033%
# B_avg_LEG_att = 5.555555555555555%
# B_avg_LEG_landed = 5.324074074074074%
# B_avg_opp_LEG_att = 3.935185185185185%
# B_avg_opp_LEG_landed = 5.092592592592593%
# B_avg_DISTANCE_att = 2.083333333333333%
# B_avg_DISTANCE_landed = 3.935185185185185%
# B_avg_opp_DISTANCE_att = 1.8518518518518516%
# B_avg_opp_DISTANCE_landed = 3.4722222222222223%
# B_avg_CLINCH_att = 5.092592592592593%
# B_avg_CLINCH_landed = 4.861111111111112%
# B_avg_opp_CLINCH_att = 2.083333333333333%
# B_avg_opp_CLINCH_landed = 2.5462962962962963%
# B_avg_GROUND_att = 4.62962962962963%
# B_avg_GROUND_landed = 3.2407407407407405%
# B_avg_opp_GROUND_att = 6.25%
# B_avg_opp_GROUND_landed = 7.4074074074074066%
# B_avg_CTRL_time(seconds) = 4.62962962962963%
# B_avg_opp_CTRL_time(seconds) = 5.092592592592593%
# B_total_time_fought(seconds) = 0.0%
# B_total_rounds_fought = 4.398148148148148%
# B_total_title_bouts = 15.972222222222221%
# B_current_win_streak = 1.8518518518518516%
# B_current_lose_streak = 1.6203703703703702%
# B_longest_win_streak = 1.8518518518518516%
# B_wins = 3.2407407407407405%
# B_losses = 4.166666666666666%
# B_draw = 0.0%
# B_win_by_Decision_Majority = 0.9259259259259258%
# B_win_by_Decision_Split = 22.916666666666664%
# B_win_by_Decision_Unanimous = 2.7777777777777777%
# B_win_by_KO/TKO = 2.5462962962962963%
# B_win_by_Submission = 6.712962962962964%
# B_win_by_TKO_Doctor_Stoppage = 4.62962962962963%
# B_Height_cms = 0.23148148148148145%
# B_Weight_lbs = 3.7037037037037033%
# R_avg_KD = 2.083333333333333%
# R_avg_opp_KD = 4.62962962962963%
# R_avg_SIG_STR_pct = 3.4722222222222223%
# R_avg_opp_SIG_STR_pct = 1.3888888888888888%
# R_avg_TD_pct = 1.1574074074074074%
# R_avg_opp_TD_pct = 1.1574074074074074%
# R_avg_SUB_ATT = 5.555555555555555%
# R_avg_opp_SUB_ATT = 7.638888888888889%
# R_avg_REV = 14.814814814814813%
# R_avg_opp_REV = 16.203703703703702%
# R_avg_SIG_STR_att = 2.083333333333333%
# R_avg_SIG_STR_landed = 1.6203703703703702%
# R_avg_opp_SIG_STR_att = 1.3888888888888888%
# R_avg_opp_SIG_STR_landed = 2.314814814814815%
# R_avg_TOTAL_STR_att = 1.8518518518518516%
# R_avg_TOTAL_STR_landed = 2.314814814814815%
# R_avg_opp_TOTAL_STR_att = 1.6203703703703702%
# R_avg_opp_TOTAL_STR_landed = 2.314814814814815%
# R_avg_TD_att = 3.7037037037037033%
# R_avg_TD_landed = 4.398148148148148%
# R_avg_opp_TD_att = 3.009259259259259%
# R_avg_opp_TD_landed = 3.4722222222222223%
# R_avg_HEAD_att = 3.2407407407407405%
# R_avg_HEAD_landed = 4.166666666666666%
# R_avg_opp_HEAD_att = 2.083333333333333%
# R_avg_opp_HEAD_landed = 3.7037037037037033%
# R_avg_BODY_att = 5.555555555555555%
# R_avg_BODY_landed = 5.092592592592593%
# R_avg_opp_BODY_att = 2.7777777777777777%
# R_avg_opp_BODY_landed = 3.7037037037037033%
# R_avg_LEG_att = 3.009259259259259%
# R_avg_LEG_landed = 2.7777777777777777%
# R_avg_opp_LEG_att = 4.166666666666666%
# R_avg_opp_LEG_landed = 3.935185185185185%
# R_avg_DISTANCE_att = 2.7777777777777777%
# R_avg_DISTANCE_landed = 1.8518518518518516%
# R_avg_opp_DISTANCE_att = 2.083333333333333%
# R_avg_opp_DISTANCE_landed = 2.314814814814815%
# R_avg_CLINCH_att = 4.861111111111112%
# R_avg_CLINCH_landed = 4.398148148148148%
# R_avg_opp_CLINCH_att = 4.166666666666666%
# R_avg_opp_CLINCH_landed = 6.018518518518518%
# R_avg_GROUND_att = 4.62962962962963%
# R_avg_GROUND_landed = 5.787037037037037%
# R_avg_opp_GROUND_att = 7.638888888888889%
# R_avg_opp_GROUND_landed = 7.638888888888889%
# R_avg_CTRL_time(seconds) = 3.009259259259259%
# R_avg_opp_CTRL_time(seconds) = 3.009259259259259%
# R_total_time_fought(seconds) = 0.4629629629629629%
# R_total_rounds_fought = 6.018518518518518%
# R_total_title_bouts = 9.027777777777777%
# R_current_win_streak = 4.166666666666666%
# R_current_lose_streak = 1.1574074074074074%
# R_longest_win_streak = 2.083333333333333%
# R_wins = 5.787037037037037%
# R_losses = 8.564814814814815%
# R_draw = 0.0%
# R_win_by_Decision_Majority = 3.7037037037037033%
# R_win_by_Decision_Split = 2.5462962962962963%
# R_win_by_Decision_Unanimous = 5.092592592592593%
# R_win_by_KO/TKO = 5.555555555555555%
# R_win_by_Submission = 10.416666666666668%
# R_win_by_TKO_Doctor_Stoppage = 8.564814814814815%
# R_Height_cms = 0.6944444444444444%
# R_Reach_cms = 2.5462962962962963%
# R_Weight_lbs = 4.62962962962963%
# B_age = 0.4629629629629629%
# R_age = 0.23148148148148145%

# %%
# Add a constant value to make all values positive
df_reach = df_number['B_Reach_cms']
df_number_positive = df_number + abs(df_number.min()) + 1

df_number_log = np.log(df_number_positive)
df_number_log['B_Reach_cms'] = df_reach
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'B_Reach_cms'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Add a constant value to make all values positive
# ----> 2 df_reach = df_number['B_Reach_cms']
#       3 df_number_positive = df_number + abs(df_number.min()) + 1
#       5 df_number_log = np.log(df_number_positive)
#
# File c:\Python311\Lib\site-packages\pandas\core\frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'B_Reach_cms'

# %%
df_id = df_test_number['id']
df_test_number.drop(['id'], axis=1, inplace=True)
df_test_number_positive = df_test_number + abs(df_test_number.min()) + 1
df_test_number_log = np.log(df_test_number_positive)
df_test_number_log = pd.concat([df_id, df_test_number_log], axis=1)

# %%
outliers = dict(check_outlier(df_number_log).sum())
print("\n\npercentage of outliers in each column:")
for key in outliers.keys():
    print(f"{key} = {outliers[key]/df_number_log[key].shape[0] * 100}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 outliers = dict(check_outlier(df_number_log).sum())
#       2 print("\n\npercentage of outliers in each column:")
#       3 for key in outliers.keys():
#
# NameError: name 'df_number_log' is not defined

# %%
df = pd.concat([df_object, df_number_log], axis=1)

# %%
check_null(df_test)
# Out:
# Tidak ditemukan missing value pada dataset

# %%
df['gender'] = df['weight_class'].apply(lambda x: 'women' if 'women' in x.lower() else 'male')

# %%
df.head()
# Out:
#    id  title_bout      weight_class  B_avg_KD  B_avg_opp_KD  \
# 0   0       False  WomenStrawweight      0.00          0.00
# 1   1       False      Welterweight      0.00          0.25
# 2   2       False     Featherweight      0.00          0.50
# 6   6       False      Middleweight      0.50          0.00
# 7   7       False      Middleweight      0.25          0.00
#
#    B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  \
# 0           0.493750               0.448750         0.475           0.17750
# 1           0.473125               0.371875         0.000           0.20375
# 2           0.500000               0.480000         0.615           0.00000
# 6           0.675000               0.550000         0.500           0.20000
# 7           0.570000               0.157500         0.595           0.08250
#
#    B_avg_SUB_ATT  ...  R_win_by_KO/TKO  R_win_by_Submission  \
# 0            0.0  ...                0                    0
# 1            0.0  ...                2                    0
# 2            0.0  ...                0                    0
# 6            0.0  ...                6                    1
# 7            0.5  ...                2                    0
#
#    R_win_by_TKO_Doctor_Stoppage  R_Stance  R_Height_cms  R_Reach_cms  \
# 0                             0  Orthodox        154.94       152.40
# 1                             0  Orthodox        170.18       182.88
# 2                             0  Orthodox        170.18       177.80
# 6                             0  Southpaw        185.42       187.96
# 7                             0  Orthodox        185.42       187.96
#
#    R_Weight_lbs  B_age  R_age  gender
# 0         115.0   35.0   27.0   women
# 1         170.0   28.0   31.0    male
# 2         145.0   24.0   30.0    male
# 6         185.0   30.0   39.0    male
# 7         185.0   21.0   31.0    male
#
# [5 rows x 139 columns]

# %%
df['weight_class'] = df['weight_class'].str.replace('Women', '')

# %%
# Get all weight_class values
weight_class = df['weight_class'].unique()
weight_class
# Out:
# array(['Strawweight', 'Welterweight', 'Featherweight', 'Middleweight',
#        'Bantamweight', 'LightHeavyweight', 'Lightweight', 'Heavyweight',
#        'CatchWeight', 'Flyweight'], dtype=object)

# %%
# Create a dictionary to map weight_class values to numbers
weight_class_dict = {
    'CatchWeight' : 0,
    'Strawweight' : 1,
    'Flyweight' : 2,
    'Bantamweight' : 3,
    'Featherweight' : 4,
    'Lightweight' : 5,
    'Welterweight' : 6,
    'Middleweight' : 7,
    'LightHeavyweight' : 8,
    'Heavyweight' : 9,
    'OpenWeight' : 10,
}

gender_dict = {
    'male' : 1,
    'women' : 0
}

# %%
# Map each weight_class value to the correct number
df['weight_class'] = df['weight_class'].map(weight_class_dict)

# %%
# Map each gender value to the correct number
df['gender'] = df['gender'].map(gender_dict)

# %%
df.head()
# Out:
#    id  title_bout  weight_class  B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  \
# 0   0       False             1      0.00          0.00           0.493750
# 1   1       False             6      0.00          0.25           0.473125
# 2   2       False             4      0.00          0.50           0.500000
# 6   6       False             7      0.50          0.00           0.675000
# 7   7       False             7      0.25          0.00           0.570000
#
#    B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  ...  \
# 0               0.448750         0.475           0.17750            0.0  ...
# 1               0.371875         0.000           0.20375            0.0  ...
# 2               0.480000         0.615           0.00000            0.0  ...
# 6               0.550000         0.500           0.20000            0.0  ...
# 7               0.157500         0.595           0.08250            0.5  ...
#
#    R_win_by_KO/TKO  R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  \
# 0                0                    0                             0
# 1                2                    0                             0
# 2                0                    0                             0
# 6                6                    1                             0
# 7                2                    0                             0
#
#    R_Stance  R_Height_cms  R_Reach_cms  R_Weight_lbs  B_age  R_age  gender
# 0  Orthodox        154.94       152.40         115.0   35.0   27.0       0
# 1  Orthodox        170.18       182.88         170.0   28.0   31.0       1
# 2  Orthodox        170.18       177.80         145.0   24.0   30.0       1
# 6  Southpaw        185.42       187.96         185.0   30.0   39.0       1
# 7  Orthodox        185.42       187.96         185.0   21.0   31.0       1
#
# [5 rows x 139 columns]

# %%
# Get the remaining object columns
df_object = df.select_dtypes(include='object')

# Perform one-hot encoding
df_encoded = pd.get_dummies(df_object)

# Combine the encoded columns with the original dataframe
df = pd.concat([df, df_encoded], axis=1)

# Drop the original object columns
df.drop(df_object.columns, axis=1, inplace=True)

df.head()
# Out:
#    id  title_bout  weight_class  B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  \
# 0   0       False             1      0.00          0.00           0.493750
# 1   1       False             6      0.00          0.25           0.473125
# 2   2       False             4      0.00          0.50           0.500000
# 6   6       False             7      0.50          0.00           0.675000
# 7   7       False             7      0.25          0.00           0.570000
#
#    B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  ...  \
# 0               0.448750         0.475           0.17750            0.0  ...
# 1               0.371875         0.000           0.20375            0.0  ...
# 2               0.480000         0.615           0.00000            0.0  ...
# 6               0.550000         0.500           0.20000            0.0  ...
# 7               0.157500         0.595           0.08250            0.5  ...
#
#    R_age  gender  B_Stance_Open Stance  B_Stance_Orthodox  B_Stance_Southpaw  \
# 0   27.0       0                 False               True              False
# 1   31.0       1                 False               True              False
# 2   30.0       1                 False               True              False
# 6   39.0       1                 False              False               True
# 7   31.0       1                 False               True              False
#
#    B_Stance_Switch  R_Stance_Open Stance  R_Stance_Orthodox  \
# 0            False                 False               True
# 1            False                 False               True
# 2            False                 False               True
# 6            False                 False              False
# 7            False                 False               True
#
#    R_Stance_Southpaw  R_Stance_Switch
# 0              False            False
# 1              False            False
# 2              False            False
# 6               True            False
# 7              False            False
#
# [5 rows x 145 columns]

# %%
# Get the remaining object columns
df_test_object = df_test.select_dtypes(include='object')

# Perform one-hot encoding
df_test_encoded = pd.get_dummies(df_test_object)

# Combine the encoded columns with the original dataframe
df_test = pd.concat([df_test, df_test_encoded], axis=1)

# Drop the original object columns
df_test.drop(df_test_object.columns, axis=1, inplace=True)

df_test.head()
# Out:
#    weight_class   id  B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  \
# 0             1  0.0  0.405465      0.000000           0.500775
# 1             3  1.0  0.000000      0.000000           0.521766
# 2             7  2.0  0.450380      0.363118           0.532600
# 3             2  3.0  0.405465      0.000000           0.441476
# 4             3  4.0  0.000000      0.000000           0.239017
#
#    B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  \
# 0               0.392042      0.000000          0.148420       0.000000
# 1               0.398776      0.559616          0.693147       0.405465
# 2               0.401902      0.004437          0.153746       0.004324
# 3               0.343590      0.223144          0.223144       1.098612
# 4               0.402126      0.285179          0.165514       0.000000
#
#    B_avg_opp_SUB_ATT  ...     B_age     R_age  gender  B_Stance_Orthodox  \
# 0           0.000000  ...  3.951244  3.761200       0               True
# 1           0.405465  ...  3.951244  3.850148       0               True
# 2           0.226896  ...  4.204693  4.060443       1               True
# 3           0.000000  ...  3.871201  3.891820       1              False
# 4           0.000000  ...  3.891820  3.850148       1               True
#
#    B_Stance_Southpaw  B_Stance_Switch  R_Stance_Open Stance  \
# 0              False            False                 False
# 1              False            False                 False
# 2              False            False                 False
# 3               True            False                 False
# 4              False            False                 False
#
#    R_Stance_Orthodox  R_Stance_Southpaw  R_Stance_Switch
# 0               True              False            False
# 1               True              False            False
# 2              False               True            False
# 3               True              False            False
# 4              False               True            False
#
# [5 rows x 143 columns]

# %%
df = df.drop([ "R_Stance_Sideways", "B_Stance_Sideways"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df = df.drop([ "R_Stance_Sideways", "B_Stance_Sideways"], axis=1)
#
# File c:\Python311\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
#    5355     )
#
# File c:\Python311\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File c:\Python311\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['R_Stance_Sideways', 'B_Stance_Sideways'] not found in axis"

# %%
df = df.drop(columns="B_Reach_cms")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df = df.drop(columns="B_Reach_cms")
#
# File c:\Python311\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
#    5355     )
#
# File c:\Python311\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File c:\Python311\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['B_Reach_cms'] not found in axis"

# %%
df.to_csv('../Without Feature Selection/UFC_kombinasi8.csv', index=False)

# %%
from sklearn.feature_selection import SelectKBest, f_regression
# Perform feature selection using SelectKBest
selector = SelectKBest(k=25, score_func=f_regression)
X = df.drop('B_Reach_cms', axis=1) 
y = df['B_Reach_cms'] 
X_selected = selector.fit_transform(X, y)

# Get the selected feature names
selected_feature_names = X.columns[selector.get_support()]
print(selected_feature_names)
# Create a new dataframe with only the selected features
df_selected = pd.DataFrame(X_selected, columns=selected_feature_names)
df_selected.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 4
#       2 # Perform feature selection using SelectKBest
#       3 selector = SelectKBest(k=25, score_func=f_regression)
# ----> 4 X = df.drop('B_Reach_cms', axis=1)
#       5 y = df['B_Reach_cms']
#       6 X_selected = selector.fit_transform(X, y)
#
# File c:\Python311\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
#    5355     )
#
# File c:\Python311\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File c:\Python311\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['B_Reach_cms'] not found in axis"

# %%
y = df['B_Reach_cms'].reset_index(drop=True)

# %%
y
# Out:
# 0       177.80
# 1       175.26
# 2       170.18
# 3       167.64
# 4       190.50
#          ...
# 3475    162.56
# 3476    190.50
# 3477    180.34
# 3478    190.50
# 3479    195.58
# Name: B_Reach_cms, Length: 3480, dtype: float64

# %%
df_selected = pd.concat([df_selected, y], axis=1)

# %%
df_selected.to_csv('../Punya Andi/UFC_kombinasi8.csv', index=False)

# %%
df_test_id = df_test['id']
df_test = df_test.drop(columns=['id'])
df_test = df_test.reindex(columns=df_selected.columns, fill_value=0)
df_test = pd.concat([df_test_id, df_test], axis=1)

# %%
df_test.to_csv('../regression_kaggle/UFC_kombinasi8.csv', index=False)

# %%
y_has_missing_values = y.isnull().any()
print(f"Does y have any missing values? {y_has_missing_values}")
# Out:
# Does y have any missing values? False

# %%
len(y)
# Out:
# 3480

# %%
df_selected.shape
# Out:
# (3480, 26)

# %%
check_null(df_selected)
# Out:
# Tidak ditemukan missing value pada dataset
