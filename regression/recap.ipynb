# %%
# import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df_result_preprocessing = pd.read_csv('preprocessing_result.csv')
df_result_preprocessing.head(99)
# Out:
#     preprocessing_num  r_squared      rmse
# 0                 1.0   0.721365  4.952264
# 1                 2.0   0.736863  4.813585
# 2                 2.5   0.628187  5.722361
# 3                 3.0   0.714500  5.516417
# 4                 4.0   0.725463  5.409537
# 5                 4.5   0.734979  5.314890
# 6                 5.0   0.658615  5.599126
# 7                 6.0   0.693329  4.853335
# 8                 6.5   0.595431  5.575475
# 9                 7.0   0.728288  5.347110
# 10                8.0   0.742427  4.745420

# %%
df_result_model = pd.read_csv('model_result.csv')
df_result_model.head(99)
# Out:
#              model  r_squared      rmse
# 0         bayesian   0.802994  4.149953
# 1    decision_tree   0.806852  4.110143
# 2      elastic_net   0.802937  4.150562
# 3       extra_tree   0.811428  4.060158
# 4              knn   0.742427  4.745420
# 5            lasso   0.832244  3.829157
# 6           linear   0.802751  4.152520
# 7   neural_network   0.806504  4.113196
# 8    random_forest   0.825341  3.907060
# 9            ridge   0.803173  4.148063
# 10         xgboost   0.823613  3.926798

# %%
df_result_kaggle = pd.read_csv('kaggle_result.csv')

# %%
plt.figure(figsize=(10, 5))
df_result_model.plot(x='model', y='r_squared', kind='bar', legend=False)
plt.xlabel('Model')
plt.ylabel('R-squared')
plt.title('Model R-squared Results')
plt.show()

# %%
plt.figure(figsize=(10, 5))
df_result_model.plot(x='model', y='rmse', kind='bar')
plt.xlabel('Model')
plt.ylabel('RMSE')
plt.title('Model RMSE Results')
plt.show()

# %%
plt.figure(figsize=(10, 5))
df_result_preprocessing.plot(x='preprocessing_num', y='r_squared', kind='bar', legend=False)
plt.xlabel('Preprocessing num')
plt.ylabel('R-Squared')
plt.title('Preprocessing R-Squared Results')
plt.show()

# %%
plt.figure(figsize=(10, 5))
df_result_preprocessing.plot(x='preprocessing_num', y='rmse', kind='bar', legend=False)
plt.xlabel('Preprocessing num')
plt.ylabel('RMSE')
plt.title('Preprocessing RMSE Results')
plt.show()

# %%
plt.figure(figsize=(10, 5))
df_result_kaggle.plot(x='model', y='r_squared', kind='bar')
plt.xlabel('Model')
plt.ylabel('R-squared')
plt.title('Kaggle R-squared Results')
plt.show()
